# %%
# !nbqa flake8 pos_tagging.ipynb --verbose
# Out:
# pos_tagging.ipynb:cell_3:11:1: E122 continuation line missing indentation or outdented
# pos_tagging.ipynb:cell_3:11:80: E501 line too long (80 > 79 characters)
# pos_tagging.ipynb:cell_3:27:45: E231 missing whitespace after ','
# pos_tagging.ipynb:cell_3:28:17: E128 continuation line under-indented for visual indent
# flake8.options.config     MainProcess    364 WARNING  ignoring unparseable config c:\Users\YNA\ET6-CDSP-group-21-repo\4_data_analysis\.flake8: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# flake8.options.config     MainProcess    366 WARNING  ignoring unparseable config c:\Users\YNA\ET6-CDSP-group-21-repo\.flake8: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# flake8.checker            MainProcess    849 INFO     Making checkers
#
# flake8.main.application   MainProcess    960 INFO     Finished running
#
# flake8.main.application   MainProcess    961 INFO     Reporting errors
#
# ...

# %%
# Check if config is being read
# !nbqa flake8 --version pos_tagging.ipynb

# Or check what config flake8 is using
# !flake8 --help | grep -A5 "Configuration"
# Out:
# nbqa 1.9.1
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !ruff format pos_tagging.ipynb
# Out:
# 1 file reformatted

# %%
# !nbqa flake8 pos_tagging.ipynb
